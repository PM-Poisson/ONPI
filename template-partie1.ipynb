# %%
# math librairies
import numpy as np
from scipy import ndimage

from plotly import express as px
import pandas               # used with plotly

# 2D image processing 
import cv2

# custom librairies
import imicpe
import imicpe.optim as optim
print(imicpe.__version__)
# Out:
# 1.0.14

# %% [markdown]
# # **Initialisation**

# %% [markdown]
# ## Fonction de coût

# %%
# fonction de coût
def E(x):
    return ...

# %% [markdown]
# # **Algorithme**

# %%
# paramètres de l'algo
Niter = ...                                 # nombre max d'itérations

# initialisation des variables
En = np.zeros((Niter+1,),float) * np.nan

N  = ...									# taille de x
xn = np.zeros((Niter+1,N),float) * np.nan
xn[0] = ...									# valeur initiale x0

# itérations
for it in range(Niter):
	xn[it+1] = ...
    
	En[it+1] = E(xn[it+1])
    

xhat = xn[-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2 Niter = ...                                 # nombre max d'itérations
#       4 # initialisation des variables
# ----> 5 En = np.zeros((Niter+1,),float) * np.nan
#       7 N  = ...									# taille de x
#       8 xn = np.zeros((Niter+1,N),float) * np.nan
#
# TypeError: unsupported operand type(s) for +: 'ellipsis' and 'int'

# %% [markdown]
# ## **Affichage des résultats**

# %%
# fonction de coût
plt_cost = pandas.DataFrame({'x':np.arange(len(En)), 'y':En, 'legend':'cost'})

fig = px.line(plt_cost,
              x='x', 
              y='y', 
              log_x=True, log_y=True,
              labels={'x':'itérations (logscale)','y':'E(x^k) (logscale)'},
              title='Évolution de la fonction de coût en fonction des itérations',
              width=800, height=350)
fig.show()

# %%
# résultat    
if N == 1:
    xn = xn.flatten()
    data = pandas.DataFrame({'x':xn, 'y':xn**2, 'iter':np.arange(Niter)})
    
    fig = px.scatter(data, x='x', y='y',  
                color='iter',       
                labels={'x':'xn[it]','y':'xn[it]**2'},
                # size='iter',
                )
    
    t = np.linspace(0,xn[0]+1,20)
    fig.add_traces(px.line(x=t, y=t**2, color_discrete_sequence=['black'] ).data)

    fig.update_layout(coloraxis_colorbar=dict(
        title=dict(text="Numéro d'itération"),
    ))
else: 
    data = pandas.DataFrame({'x':np.arange(N), 'y':xn[0], 'iteration':'0'})
    for it in range(0,Niter,Niter//10):
        plt_xn = pandas.DataFrame({'x':np.arange(N), 'y':xn[it], 'iteration':str(it)})
        data   = pandas.concat([data,plt_xn]) 

    myscale = px.colors.sample_colorscale(
        colorscale=px.colors.sequential.Plasma,
        samplepoints=len(data['iteration'].unique()),
        low=0.0, high=1.0,
        colortype="rgb",
    )

    fig = px.line(data,
                x='x',
                y='y', 
                color='iteration',    #color_discrete_sequence=['black','orange', 'orangered'],
                color_discrete_sequence=myscale,           
                labels={'x':'indices','y':''},
                # title='Signaux', 
                markers=True,
                width=800, height=450)


fig.show()
